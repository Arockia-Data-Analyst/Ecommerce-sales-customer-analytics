# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df.head()

# %%
df.info()

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID             str
# Order Date           str
# Ship Date            str
# Ship Mode            str
# Customer ID          str
# Customer Name        str
# Segment              str
# Country              str
# City                 str
# State                str
# Postal Code        int64
# Region               str
# Product ID           str
# Category             str
# Sub-Category         str
# Product Name         str
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df['Order Date'] = pd.to_datetime(df['Order Date'])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:1036, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, origin, cache)
#    1034             result = arg.tz_localize("utc")
#    1035 elif isinstance(arg, ABCSeries):
# -> 1036     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1037     if not cache_array.empty:
#    1038         result = arg.map(cache_array)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:254, in _maybe_cache(arg, format, cache, convert_listlike)
#     252 unique_dates = unique(arg)
#     253 if len(unique_dates) < len(arg):
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format='%m/%d/%Y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df['Order Date'] = pd.to_datetime(df['Order Date'], format='%m/%d/%Y')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:1036, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, origin, cache)
#    1034             result = arg.tz_localize("utc")
#    1035 elif isinstance(arg, ABCSeries):
# -> 1036     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1037     if not cache_array.empty:
#    1038         result = arg.map(cache_array)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:254, in _maybe_cache(arg, format, cache, convert_listlike)
#     252 unique_dates = unique(arg)
#     253 if len(unique_dates) < len(arg):
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format='mixed')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   datetime64[us]
#  3   Ship Date      9994 non-null   str
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
# ...

# %%
df['Year'] = df['Order Date'].dt.year

# %%
df['Month'] = df['Order Date'].dt.month_name()

# %%
df[['Order Date','Year','Month']].head()
# Out:
#   Order Date  Year     Month
# 0 2016-11-08  2016  November
# 1 2016-11-08  2016  November
# 2 2016-06-12  2016      June
# 3 2015-10-11  2015   October
# 4 2015-10-11  2015   October

# %%
df['Sales'].sum()
# Out:
# np.float64(2297200.8603)

# %%
df['Profit'].sum()
# Out:
# np.float64(286397.0217)

# %%
df['Order ID'].nunique()
# Out:
# 5009

# %%
df['Customer ID'].nunique()
# Out:
# 793

# %%
monthly_sales = df.groupby('Month')['Sales'].sum()

# %%
df.groupby('Month')['Sales'].sum()
# Out:
# Month
# April        137762.1286
# August       159044.0630
# December     325293.5035
# February      59751.2514
# January       94924.8356
# July         147238.0970
# June         152718.6793
# March        205005.4888
# May          155028.8117
# November     352461.0710
# October      200322.9847
# September    307649.9457
# Name: Sales, dtype: float64

# %%
monthly_sales = df.groupby('Month')['Sales'].sum()

# %%
monthly_sales
# Out:
# Month
# April        137762.1286
# August       159044.0630
# December     325293.5035
# February      59751.2514
# January       94924.8356
# July         147238.0970
# June         152718.6793
# March        205005.4888
# May          155028.8117
# November     352461.0710
# October      200322.9847
# September    307649.9457
# Name: Sales, dtype: float64

# %%
monthly_sales.plot(kind='line',figsize=(10,5),color='darkblue',marker='o')
# Out:
# <Axes: xlabel='Month'>

# %%
monthly_sales.plot(kind='line',figsize=(10,5),color='yellow',marker='o')
# Out:
# <Axes: xlabel='Month'>

# %%
monthly_sales.plot(kind='line',figsize=(10,5),color='red',marker='o')
# Out:
# <Axes: xlabel='Month'>

# %%
monthly_sales.plot(kind='line',figsize=(10,5),color='darkblue',marker='o',markerfacecolor='darkred',markersize=10)
# Out:
# <Axes: xlabel='Month'>

# %%
monthly_sales.plot(kind='line',figsize=(10,5),color='darkblue',marker='o',markerfacecolor='darkred',markersize=10)
plt.title('Monthly Sales Trend',fontsize=18,fontweight='bold')
plt.xlabel('Month', fontsize=12)
plt.ylabel('Sales', fontsize=12)
plt.grid(color='black')
plt.show()

# %%
monthly_sales.plot(kind='line',figsize=(10,5),color='darkblue',marker='o',markerfacecolor='darkred',markersize=10)
plt.title('Monthly Sales Trend',fontsize=18,fontweight='bold')
plt.xlabel('Month', fontsize=12)
plt.ylabel('Sales', fontsize=12)
plt.dotgrid(color='black')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 5
#       1 monthly_sales.plot(kind='line',figsize=(10,5),color='darkblue',marker='o',markerfacecolor='darkred',markersize=10)
#       2 plt.title('Monthly Sales Trend',fontsize=18,fontweight='bold')
#       3 plt.xlabel('Month', fontsize=12)
#       4 plt.ylabel('Sales', fontsize=12)
# ----> 5 plt.dotgrid(color='black')
#       6 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'dotgrid'

# %%
monthly_sales.plot(kind='line',figsize=(10,5),color='darkblue',marker='o',markerfacecolor='darkred',markersize=10)
plt.title('Monthly Sales Trend',fontsize=18,fontweight='bold')
plt.xlabel('Month', fontsize=12)
plt.ylabel('Sales', fontsize=12)
plt.grid(color='black',linestyle='--')
plt.show()

# %%
monthly_sales.plot(kind='line',figsize=(10,5),color='darkblue',marker='o',markerfacecolor='darkred',markersize=10)
plt.title('Monthly Sales Trend',fontsize=18,fontweight='bold')
plt.xlabel('Month', fontsize=12)
plt.ylabel('Sales', fontsize=12)
plt.grid(axis='y',color='black',linestyle='--')
plt.show()

# %%
monthly_sales.plot(kind='line',figsize=(10,5),color='darkblue',marker='o',markerfacecolor='darkred',markersize=10,fontsize=20)
plt.title('Monthly Sales Trend',fontsize=25,fontweight='bold')
plt.xlabel('Month', fontsize=21)
plt.ylabel('Sales', fontsize=21)
plt.grid(axis='y',color='black',linestyle='--')
plt.show()

# %%
monthly_sales.plot(kind='line',figsize=(10,5),color='darkblue',marker='o',markerfacecolor='darkred',markersize=10,fontsize=20)
plt.title('Monthly Sales Trend',fontsize=25,fontweight='bold')
plt.xlabel('Month', fontsize=21,color='orange')
plt.ylabel('Sales', fontsize=21,color='orange')
plt.grid(axis='y',color='black',linestyle='--')
plt.show()

# %%
monthly_sales.plot(kind='line',figsize=(10,5),color='darkblue',marker='o',markerfacecolor='darkred',markersize=10,fontsize=20)
plt.title('Monthly Sales Trend',fontsize=25,fontweight='bold')
plt.xlabel('Month', fontsize=21,color='orange')
plt.ylabel('Sales', fontsize=21,color='orange')
plt.grid(axis='y',color='black',linestyle='--')
plt.show()

# %%
monthly_sales.plot(kind='line',figsize=(10,5),color='darkblue',marker='o',markerfacecolor='darkred',markersize=10,fontsize=20)
plt.title('Monthly Sales Trend',fontsize=25,fontweight='bold')
plt.xlabel('Month', fontsize=21,color='orange')
plt.ylabel('Sales', fontsize=21,color='orange')
plt.grid(axis='y',color='black',linestyle='--')
plt.show()

# %%
month_order = ['January','February','March','April','May','June','July','August','September','October','November','December']
df['Month'] = pd.Categorical(df['Month'],categories=month_order,ordered=True)

# %%
monthly_sales = df.groupby('Month')['Sales'].sum()

# %%
monthly_sales
# Out:
# Month
# January       94924.8356
# February      59751.2514
# March        205005.4888
# April        137762.1286
# May          155028.8117
# June         152718.6793
# July         147238.0970
# August       159044.0630
# September    307649.9457
# October      200322.9847
# November     352461.0710
# December     325293.5035
# Name: Sales, dtype: float64

# %%
monthly_sales.plot(kind='line',figsize=(10,5),color='darkblue',marker='o',markerfacecolor='darkred',markersize=10,fontsize=10)
plt.title('Monthly Sales Trend',fontsize=15,fontweight='bold')
plt.xlabel('Month', fontsize=12,color='orange')
plt.ylabel('Sales', fontsize=12,color='orange')
plt.grid(axis='y',color='black',linestyle='--')
plt.show()

# %%
monthly_sales.plot(kind='line',figsize=(14,6),color='darkblue',marker='o',markerfacecolor='darkred',markersize=10,fontsize=10)
plt.title('Monthly Sales Trend',fontsize=15,fontweight='bold')
plt.xlabel('Month', fontsize=12,color='orange')
plt.ylabel('Sales', fontsize=12,color='orange')
plt.grid(axis='y',color='black',linestyle='--')
plt.show()

# %%
monthly_sales.plot(kind='line',figsize=(14,6),color='darkblue',marker='o',markerfacecolor='darkred',markersize=10,fontsize=10)
plt.title('Monthly Sales Trend',fontsize=15,fontweight='bold')
plt.xlabel('Month', fontsize=12,color='orange')
plt.ylabel('Sales', fontsize=12,color='orange')
plt.grid(axis='y',color='black',linestyle='--')
plt.xticks(rotation=45)
plt.show()

# %%
monthly_sales.plot(kind='line',figsize=(14,6),color='darkblue',marker='o',markerfacecolor='darkred',markersize=10,fontsize=10)
plt.title('Monthly Sales Trend',fontsize=15,fontweight='bold')
plt.xlabel('Month', fontsize=12,color='orange')
plt.ylabel('Sales', fontsize=12,color='orange')
plt.grid(axis='y',color='black',linestyle='--')
plt.xticks(monthly_sales.index)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:1811, in Axis.convert_units(self, x)
#    1810 try:
# -> 1811     ret = self._converter.convert(x, self.units, self)
#    1812 except Exception as e:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 StrCategoryConverter._validate_unit(unit)
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# ...

# %%
monthly_sales.plot(kind='line',figsize=(14,6),color='darkblue',marker='o',markerfacecolor='darkred',markersize=10,fontsize=10)
plt.title('Monthly Sales Trend',fontsize=15,fontweight='bold')
plt.xlabel('Month', fontsize=12,color='orange')
plt.ylabel('Sales', fontsize=12,color='orange')
plt.grid(axis='y',color='black',linestyle='--')
plt.xticks(monthly_sales.index,rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:1811, in Axis.convert_units(self, x)
#    1810 try:
# -> 1811     ret = self._converter.convert(x, self.units, self)
#    1812 except Exception as e:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 StrCategoryConverter._validate_unit(unit)
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# ...

# %%
monthly_sales.plot(kind='line',figsize=(14,6),color='darkblue',marker='o',markerfacecolor='darkred',markersize=10,fontsize=10)
plt.title('Monthly Sales Trend',fontsize=15,fontweight='bold')
plt.xlabel('Month', fontsize=12,color='orange')
plt.ylabel('Sales', fontsize=12,color='orange')
plt.grid(axis='y',color='black',linestyle='--')
plt.xticks(rotation=45)
plt.show()

# %%
monthly_sales.plot(kind='line',figsize=(14,6),color='darkblue',marker='o',markerfacecolor='darkred',markersize=10,fontsize=10)
plt.title('Monthly Sales Trend',fontsize=15,fontweight='bold')
plt.xlabel('Month', fontsize=12,color='orange')
plt.ylabel('Sales', fontsize=12,color='orange')
plt.grid(axis='y',color='black',linestyle='--')
plt.xticks(ticks=range(len(monthly_sales.index)),labels=monthly_sales.index,rotation=45)
plt.show()

# %%
monthly_sales.plot(kind='line',figsize=(14,6),color='darkblue',marker='o',markerfacecolor='darkred',markeredgewidth=1,markersize=10,fontsize=10)
plt.title('Monthly Sales Trend',fontsize=15,fontweight='bold')
plt.xlabel('Month', fontsize=12,color='orange')
plt.ylabel('Sales', fontsize=12,color='orange')
plt.grid(axis='y',color='lightgray',linestyle='--')
plt.figure(facecolor='#F5F7FA')
plt.xticks(ticks=range(len(monthly_sales.index)),labels=monthly_sales.index,rotation=45)
plt.show()

# %%
monthly_sales.plot(kind='line',figsize=(14,6),color='darkblue',marker='o',markerfacecolor='darkred',markeredgewidth=1,markersize=10,fontsize=10)
plt.title('Monthly Sales Trend',fontsize=15,fontweight='bold')
plt.xlabel('Month', fontsize=12,color='orange')
plt.ylabel('Sales', fontsize=12,color='orange')
plt.grid(axis='y',color='lightgray',linestyle='--')
plt.figure(facecolor='#F5F7FA')
plt.xticks(ticks=range(len(monthly_sales.index)),labels=monthly_sales.index,rotation=45)
plt.show()

# %%
plt.figure(facecolor='#F5F7FA')
monthly_sales.plot(kind='line',figsize=(14,6),color='darkblue',marker='o',markerfacecolor='darkred',markeredgewidth=1,markersize=10,fontsize=10)
plt.title('Monthly Sales Trend',fontsize=15,fontweight='bold')
plt.xlabel('Month', fontsize=12,color='orange')
plt.ylabel('Sales', fontsize=12,color='orange')
plt.grid(axis='y',color='lightgray',linestyle='--')
plt.xticks(ticks=range(len(monthly_sales.index)),labels=monthly_sales.index,rotation=45)
plt.show()

# %%
plt.figure(figsize=(14,6),facecolor='#F5F7FA')
monthly_sales.plot(kind='line',color='darkblue',marker='o',markerfacecolor='darkred',markeredgewidth=1,markersize=10,fontsize=10)
plt.title('Monthly Sales Trend',fontsize=15,fontweight='bold')
plt.xlabel('Month', fontsize=12,color='orange')
plt.ylabel('Sales', fontsize=12,color='orange')
plt.grid(axis='y',color='lightgray',linestyle='--')
plt.xticks(ticks=range(len(monthly_sales.index)),labels=monthly_sales.index,rotation=45)
plt.show()

# %%
plt.figure(figsize=(14,6),facecolor='#F5F7FB')
monthly_sales.plot(kind='line',color='darkblue',marker='o',markerfacecolor='darkred',markeredgewidth=1,markersize=10,fontsize=10)
plt.title('Monthly Sales Trend',fontsize=15,fontweight='bold')
plt.xlabel('Month', fontsize=12,color='orange')
plt.ylabel('Sales', fontsize=12,color='orange')
plt.grid(axis='y',color='lightgray',linestyle='--')
plt.xticks(ticks=range(len(monthly_sales.index)),labels=monthly_sales.index,rotation=45)
plt.show()

# %%
plt.figure(figsize=(14,6),facecolor='lightblue')
monthly_sales.plot(kind='line',color='darkblue',marker='o',markerfacecolor='darkred',markeredgewidth=1,markersize=10,fontsize=10)
plt.title('Monthly Sales Trend',fontsize=15,fontweight='bold')
plt.xlabel('Month', fontsize=12,color='orange')
plt.ylabel('Sales', fontsize=12,color='orange')
plt.fill_between(monthly_sales.index,monthly_sales.values,color='skyblue',alpha=0.3)
plt.grid(axis='y',color='lightgray',linestyle='--')
plt.xticks(ticks=range(len(monthly_sales.index)),labels=monthly_sales.index,rotation=45)
plt.show()

# %%
plt.figure(figsize=(14,6),facecolor='red')
monthly_sales.plot(kind='line',color='darkblue',marker='o',markerfacecolor='darkred',markeredgewidth=1,markersize=10,fontsize=10)
plt.title('Monthly Sales Trend',fontsize=15,fontweight='bold')
plt.xlabel('Month', fontsize=12,color='orange')
plt.ylabel('Sales', fontsize=12,color='orange')
plt.fill_between(monthly_sales.index,monthly_sales.values,color='skyblue',alpha=0.3)
plt.grid(axis='y',color='lightgray',linestyle='--')
plt.xticks(ticks=range(len(monthly_sales.index)),labels=monthly_sales.index,rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,6),facecolor='#F5F7FA')
category_sales.plot(kind='bar',color=['#1F4E79','#4F81BD','#FF8C00'],edgecolor='black')
plt.title('Sales by Category',fontsize=22,fontweight='bold')
plt.xlabel('Category',fontsize=16,color='darkorange')
plt.ylabel('Sales',fontsize=16,color='darkorange')
plt.xticks(rotation=0)
plt.grid(axis='y',color='lightgray',linestyle='--',linewidth=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 2
#       1 plt.figure(figsize=(10,6),facecolor='#F5F7FA')
# ----> 2 category_sales.plot(kind='bar',color=['#1F4E79','#4F81BD','#FF8C00'],edgecolor='black')
#       3 plt.title('Sales by Category',fontsize=22,fontweight='bold')
#       4 plt.xlabel('Category',fontsize=16,color='darkorange')
#       5 plt.ylabel('Sales',fontsize=16,color='darkorange')
#
# NameError: name 'category_sales' is not defined

# %%
category_sales = df.groupby('Category')['Sales'].sum()

# %%
category_sales
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(10,6),facecolor='#F5F7FA')
category_sales.plot(kind='bar',color=['#1F4E79','#4F81BD','#FF8C00'],edgecolor='black')
plt.title('Sales by Category',fontsize=22,fontweight='bold')
plt.xlabel('Category',fontsize=16,color='darkorange')
plt.ylabel('Sales',fontsize=16,color='darkorange')
plt.xticks(rotation=0)
plt.grid(axis='y',color='lightgray',linestyle='--',linewidth=0.5)
plt.show()

# %%
plt.figure(figsize=(10,4),facecolor='#F5F7FA')
category_sales.plot(kind='bar',color=['#1F4E79','#4F81BD','#FF8C00'],edgecolor='black')
plt.title('Sales by Category',fontsize=22,fontweight='bold')
plt.xlabel('Category',fontsize=16,color='darkorange')
plt.ylabel('Sales',fontsize=16,color='darkorange')
plt.xticks(rotation=0)
plt.grid(axis='y',color='gray',linestyle='--',linewidth=0.5)
plt.show()

# %%
plt.figure(figsize=(10,6),facecolor='#F5F7FA')
category_sales.plot(kind='bar',color=['#1F4E79','#4F81BD','#FF8C00'],edgecolor='black',alpha=0.9)
plt.title('Sales by Category',fontsize=22,fontweight='bold')
plt.xlabel('Category',fontsize=16,color='darkorange')
plt.ylabel('Sales',fontsize=16,color='darkorange')
plt.xticks(rotation=0)
plt.box(False)
plt.grid(axis='y',color='gray',linestyle='--',linewidth=0.5)
for i, value in enumerate(category_sales):
    plt.text(
        i,
        value + 10000,
        f'{value:,.0f}',
        ha='center',
        fontsize=12,
        fontweight='bold'
    )
plt.show()

# %%
plt.figure(figsize=(10,6),facecolor='#F5F7FA')
category_sales.plot(kind='bar',color=['#1F4E79','#4F81BD','#FF8C00'],edgecolor='black',alpha=0.9)
plt.title('Sales by Category',fontsize=22,fontweight='bold')
plt.xlabel('Category',fontsize=16,color='darkorange')
plt.ylabel('Sales',fontsize=16,color='darkorange')
plt.xticks(rotation=0)
plt.box(False)
plt.grid(axis='y',color='gray',linestyle='--',linewidth=0.5)
plt.box(top='false',right='false')
for i, value in enumerate(category_sales):
    plt.text(
        i,
        value + 10000,
        f'{value:,.0f}',
        ha='center',
        fontsize=12,
        fontweight='bold'
    )
plt.show()

# %%
plt.figure(figsize=(10,6),facecolor='#F5F7FA')
category_sales.plot(kind='bar',color=['#1F4E79','#4F81BD','#FF8C00'],edgecolor='black',alpha=0.9)
plt.title('Sales by Category',fontsize=22,fontweight='bold')
plt.xlabel('Category',fontsize=16,color='darkorange')
plt.ylabel('Sales',fontsize=16,color='darkorange')
plt.xticks(rotation=0)
plt.grid(axis='y',color='gray',linestyle='--',linewidth=0.5)
for i, value in enumerate(category_sales):
    plt.text(
        i,
        value + 10000,
        f'{value:,.0f}',
        ha='center',
        fontsize=12,
        fontweight='bold'
    )
plt.show()

# %%
plt.figure(figsize=(10,6),facecolor='#F5F7FA')
category_sales.plot(kind='bar',color=['#1F4E79','#4F81BD','#FF8C00'],edgecolor='black',alpha=0.9)
plt.title('Sales by Category',fontsize=22,fontweight='bold')
plt.xlabel('Category',fontsize=16,color='darkorange')
plt.ylabel('Sales',fontsize=16,color='darkorange')
plt.xticks(rotation=0)
plt.grid(axis='y',color='gray',linestyle='--',linewidth=0.5)
plt.box(top=False,right=False)
for i, value in enumerate(category_sales):
    plt.text(
        i,
        value + 10000,
        f'{value:,.0f}',
        ha='center',
        fontsize=12,
        fontweight='bold'
    )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 9
#       5 plt.ylabel('Sales',fontsize=16,color='darkorange')
#       6 plt.xticks(rotation=0)
#       7 plt.box(False)
#       8 plt.grid(axis='y',color='gray',linestyle='--',linewidth=0.5)
# ----> 9 plt.box(top='false',right='false')
#      10 for i, value in enumerate(category_sales):
#      11     plt.text(
#      12         i,
#
# TypeError: box() got an unexpected keyword argument 'top'

# %%
plt.figure(figsize=(10,6),facecolor='#F5F7FA')
category_sales.plot(kind='bar',color=['#1F4E79','#4F81BD','#FF8C00'],edgecolor='black',alpha=0.9)
plt.title('Sales by Category',fontsize=22,fontweight='bold')
plt.xlabel('Category',fontsize=16,color='darkorange')
plt.ylabel('Sales',fontsize=16,color='darkorange')
plt.xticks(rotation=0)
plt.grid(axis='y',color='gray',linestyle='--',linewidth=0.5)
plt.box(top=0,right=0)
for i, value in enumerate(category_sales):
    plt.text(
        i,
        value + 10000,
        f'{value:,.0f}',
        ha='center',
        fontsize=12,
        fontweight='bold'
    )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 8
#       4 plt.xlabel('Category',fontsize=16,color='darkorange')
#       5 plt.ylabel('Sales',fontsize=16,color='darkorange')
#       6 plt.xticks(rotation=0)
#       7 plt.grid(axis='y',color='gray',linestyle='--',linewidth=0.5)
# ----> 8 plt.box(top=False,right=False)
#       9 for i, value in enumerate(category_sales):
#      10     plt.text(
#      11         i,
#
# TypeError: box() got an unexpected keyword argument 'top'

# %%
plt.figure(figsize=(10,6),facecolor='#F5F7FA')
category_sales.plot(kind='bar',color=['#1F4E79','#4F81BD','#FF8C00'],edgecolor='black',alpha=0.9)
plt.title('Sales by Category',fontsize=22,fontweight='bold')
plt.xlabel('Category',fontsize=16,color='darkorange')
plt.ylabel('Sales',fontsize=16,color='darkorange')
plt.xticks(rotation=0)
plt.grid(axis='y',color='gray',linestyle='--',linewidth=0.5)
plt.box(top=0,right=0)
for i, value in enumerate(category_sales):
    plt.text(
        i,
        value + 10000,
        f'{value:,.0f}',
        ha='center',
        fontsize=12,
        fontweight='bold'
    )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 8
#       4 plt.xlabel('Category',fontsize=16,color='darkorange')
#       5 plt.ylabel('Sales',fontsize=16,color='darkorange')
#       6 plt.xticks(rotation=0)
#       7 plt.grid(axis='y',color='gray',linestyle='--',linewidth=0.5)
# ----> 8 plt.box(top=0,right=0)
#       9 for i, value in enumerate(category_sales):
#      10     plt.text(
#      11         i,
#
# TypeError: box() got an unexpected keyword argument 'top'

# %%
plt.figure(figsize=(10,6),facecolor='#F5F7FA')
category_sales.plot(kind='bar',color=['#1F4E79','#4F81BD','#FF8C00'],edgecolor='black',alpha=0.9)
plt.title('Sales by Category',fontsize=22,fontweight='bold')
plt.xlabel('Category',fontsize=16,color='darkorange')
plt.ylabel('Sales',fontsize=16,color='darkorange')
plt.xticks(rotation=0)
plt.box(False)
plt.grid(axis='y',color='gray',linestyle='--',linewidth=0.5)
for i, value in enumerate(category_sales):
    plt.text(
        i,
        value + 10000,
        f'{value:,.0f}',
        ha='center',
        fontsize=12,
        fontweight='bold'
    )
plt.show()

# %%
plt.figure(figsize=(10,6),facecolor='#F5F7FA')
category_sales.plot(kind='bar',color=['#1F4E79','#4F81BD','#FF8C00'],edgecolor='black',alpha=0.9)
plt.title('Sales by Category',fontsize=22,fontweight='bold')
plt.xlabel('Category',fontsize=16,color='darkorange')
plt.ylabel('Sales',fontsize=16,color='darkorange')
plt.xticks(rotation=0)
plt.grid(axis='y',color='gray',linestyle='--',linewidth=0.5)
for i, value in enumerate(category_sales):
    plt.text(
        i,
        value + 10000,
        f'{value:,.0f}',
        ha='center',
        fontsize=12,
        fontweight='bold'
    )
plt.show()

# %%
plt.figure(figsize=(10,6),facecolor='#F5F7FA')
category_sales.plot(kind='bar',color=['#1F4E79','#4F81BD','#FF8C00'],edgecolor='black',alpha=0.9)
plt.title('Sales by Category',fontsize=22,fontweight='bold')
plt.xlabel('Category',fontsize=16,color='darkorange')
plt.ylabel('Sales',fontsize=16,color='darkorange')
plt.xticks(rotation=0)
plt.grid(axis='y',color='gray',linestyle='--',linewidth=0.5)
for i, value in enumerate(category_sales):
    plt.text(
        i,
        value + 10000,
        f'{value:,.0f}',
        ha='center',
        fontsize=12,
        fontweight='bold'
    )
ax = plt.gca()

ax.spines['top'].set_visible(False)

ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('gray')

ax.spines['bottom'].set_color('gray')
plt.show()

# %%
category_profit = df.groupby('Category')['Profit'].sum()

# %%
category_profit
# Out:
# Category
# Furniture           18451.2728
# Office Supplies    122490.8008
# Technology         145454.9481
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(10,6),facecolor='#F5F7FA')
category_profit.plot(kind='bar',color=['#2E8B57','#66CDAA','#FF8C00'],edgecolor='black',alpha=0.9)
plt.title('Profit by Category',fontsize=24,fontweight='bold')
plt.xlabel('Category',fontsize=16,color='darkgreen')
plt.ylabel('Profit',fontsize=16,color='darkgreen')
plt.grid(axis='y',color='lightgray',linestyle='--',linewidth=0.5)
for i, value in enumerate(category_profit):
    plt.text(
        i,
        value + 1000,
        f'{value:,.0f}',
        ha='center',
        fontsize=12,
        fontweight='bold'
    )
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.show()

# %%
region_sales=df.gruopby('Region')['Sales'].sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 region_sales=df.gruopby('Region')['Sales'].sum()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'gruopby'

# %%
region_sales=df.groupby('Region')['Sales'].sum()

# %%
region_sales
# Out:
# Region
# Central    501239.8908
# East       678781.2400
# South      391721.9050
# West       725457.8245
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(10,6),facecolor='#F5F7FA')
region_sales.plot(kind='bar',color=['#1F4E79','#4F81BD','#66CDAA','#FF8C00'],edgecolor='black',alpha=0.9)
plt.title('Sales by Region',fontsize=24,fontweight='bold')
plt.xlabel('Region',fontsize=16,color='darkorange')
plt.ylabel('Sales',fontsize=16,color='darkorange')
plt.grid(axis='y',color='lightgray',linestyle='--',linewidth=0.5)
for i, value in enumerate(region_sales):

    plt.text(
        i,
        value + 10000,
        f'{value:,.0f}',
        ha='center',
        fontsize=12,
        fontweight='bold'
    )
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()

# %%
region_profit = df.groupby('Region')['Profit'].sum()

# %%
region_profit
# Out:
# Region
# Central     39706.3625
# East        91522.7800
# South       46749.4303
# West       108418.4489
# Name: Profit, dtype: float64

# %%
plt.figure(
    figsize=(10,6),
    facecolor='#F5F7FA'
)

region_profit.plot(
    kind='bar',
    color=['#2E8B57','#66CDAA','#20B2AA','#FF8C00'],
    edgecolor='black',
    alpha=0.9
)
plt.title(
    'Profit by Region',
    fontsize=24,
    fontweight='bold'
)

plt.xlabel(
    'Region',
    fontsize=16,
    color='darkgreen'
)

plt.ylabel(
    'Profit',
    fontsize=16,
    color='darkgreen'
)
plt.grid(
    axis='y',
    color='lightgray',
    linestyle='--',
    linewidth=0.5
)
for i, value in enumerate(region_profit):

    plt.text(
        i,
        value + 1000,
        f'{value:,.0f}',
        ha='center',
        fontsize=12,
        fontweight='bold'
    )
ax = plt.gca()

ax.spines['top'].set_visible(False)

ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()

# %%
segment_sales = df.groupby('Segment')['Sales'].sum()

# %%
segment_sales
# Out:
# Segment
# Consumer       1.161401e+06
# Corporate      7.061464e+05
# Home Office    4.296531e+05
# Name: Sales, dtype: float64

# %%
plt.figure(
    figsize=(10,6),
    facecolor='#F5F7FA'
)

segment_sales.plot(
    kind='bar',
    color=['#1F4E79','#4F81BD','#FF8C00'],
    edgecolor='black',
    alpha=0.9
)
plt.title(
    'Sales by Customer Segment',
    fontsize=24,
    fontweight='bold'
)

plt.xlabel(
    'Customer Segment',
    fontsize=16,
    color='darkorange'
)

plt.ylabel(
    'Sales',
    fontsize=16,
    color='darkorange'
)
plt.grid(
    axis='y',
    color='lightgray',
    linestyle='--',
    linewidth=0.5
)
for i, value in enumerate(segment_sales):

    plt.text(
        i,
        value + 10000,
        f'{value:,.0f}',
        ha='center',
        fontsize=12,
        fontweight='bold'
    )
ax = plt.gca()

ax.spines['top'].set_visible(False)

ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()

# %%
top_customers = df.groupby('Customer Name')['Sales'].sum().sort_values(ascending=False).head(10)

# %%
top_customers
# Out:
# Customer Name
# Sean Miller           25043.050
# Tamara Chand          19052.218
# Raymond Buch          15117.339
# Tom Ashbrook          14595.620
# Adrian Barton         14473.571
# Ken Lonsdale          14175.229
# Sanjit Chand          14142.334
# Hunter Lopez          12873.298
# Sanjit Engle          12209.438
# Christopher Conant    12129.072
# Name: Sales, dtype: float64

# %%
plt.figure(
    figsize=(12,7),
    facecolor='#F5F7FA'
)

top_customers.plot(
    kind='barh',
    color='#1F4E79',
    edgecolor='black',
    alpha=0.9
)
plt.title(
    'Top 10 Customers by Sales',
    fontsize=24,
    fontweight='bold'
)

plt.xlabel(
    'Sales',
    fontsize=16,
    color='darkorange'
)

plt.ylabel(
    'Customer Name',
    fontsize=16,
    color='darkorange'
)
plt.grid(
    axis='x',
    color='lightgray',
    linestyle='--',
    linewidth=0.5
)
for i, value in enumerate(top_customers):

    plt.text(
        value + 1000,
        i,
        f'{value:,.0f}',
        va='center',
        fontsize=11,
        fontweight='bold'
    )
ax = plt.gca()

ax.spines['top'].set_visible(False)

ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()

# %%
top_products = df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)

# %%
plt.figure(
    figsize=(14,8),
    facecolor='#F5F7FA'
)

top_products.plot(
    kind='barh',
    color='#FF8C00',
    edgecolor='black',
    alpha=0.9
)
plt.title(
    'Top 10 Products by Sales',
    fontsize=24,
    fontweight='bold'
)

plt.xlabel(
    'Sales',
    fontsize=16,
    color='darkorange'
)

plt.ylabel(
    'Product Name',
    fontsize=16,
    color='darkorange'
)
plt.grid(
    axis='x',
    color='lightgray',
    linestyle='--',
    linewidth=0.5
)
for i, value in enumerate(top_products):

    plt.text(
        value + 1000,
        i,
        f'{value:,.0f}',
        va='center',
        fontsize=11,
        fontweight='bold'
    )
ax = plt.gca()

ax.spines['top'].set_visible(False)

ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()

# %%
plt.figure(
    figsize=(10,6),
    facecolor='#F5F7FA'
)

plt.scatter(
    df['Discount'],
    df['Profit'],
    color='#1F4E79',
    alpha=0.6
)
plt.title(
    'Discount vs Profit Analysis',
    fontsize=24,
    fontweight='bold'
)

plt.xlabel(
    'Discount',
    fontsize=16,
    color='darkred'
)

plt.ylabel(
    'Profit',
    fontsize=16,
    color='darkred'
)
ax = plt.gca()

ax.spines['top'].set_visible(False)

ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()

# %%
subcategory_sales = df.groupby('Sub-Category')['Sales'].sum().sort_values(ascending=False)

# %%
plt.figure(
    figsize=(14,8),
    facecolor='#F5F7FA'
)

subcategory_sales.plot(
    kind='barh',
    color='#4F81BD',
    edgecolor='black',
    alpha=0.9
)
plt.title(
    'Sales by Sub-Category',
    fontsize=24,
    fontweight='bold'
)

plt.xlabel(
    'Sales',
    fontsize=16,
    color='darkblue'
)

plt.ylabel(
    'Sub-Category',
    fontsize=16,
    color='darkblue'
)
plt.grid(
    axis='x',
    color='lightgray',
    linestyle='--',
    linewidth=0.5
)
for i, value in enumerate(subcategory_sales):

    plt.text(
        value + 1000,
        i,
        f'{value:,.0f}',
        va='center',
        fontsize=10,
        fontweight='bold'
    )
ax = plt.gca()

ax.spines['top'].set_visible(False)

ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()

# %%
state_sales = df.groupby('State')['Sales'].sum().sort_values(ascending=False).head(10)

# %%
plt.figure(
    figsize=(14,8),
    facecolor='#F5F7FA'
)

state_sales.plot(
    kind='barh',
    color='#1F4E79',
    edgecolor='black',
    alpha=0.9
)
plt.title(
    'Top 10 States by Sales',
    fontsize=24,
    fontweight='bold'
)

plt.xlabel(
    'Sales',
    fontsize=16,
    color='darkblue'
)

plt.ylabel(
    'State',
    fontsize=16,
    color='darkblue'
)
plt.grid(
    axis='x',
    color='lightgray',
    linestyle='--',
    linewidth=0.5
)
for i, value in enumerate(state_sales):

    plt.text(
        value + 1000,
        i,
        f'{value:,.0f}',
        va='center',
        fontsize=10,
        fontweight='bold'
    )
ax = plt.gca()

ax.spines['top'].set_visible(False)

ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()

# %%
shipmode_sales = df.groupby('Ship Mode')['Sales'].sum().sort_values(ascending=False)

# %%
plt.figure(
    figsize=(12,6),
    facecolor='#F5F7FA'
)

shipmode_sales.plot(
    kind='bar',
    color=['#1F4E79','#4F81BD','#66CDAA','#FF8C00'],
    edgecolor='black',
    alpha=0.9
)
plt.title(
    'Sales by Ship Mode',
    fontsize=24,
    fontweight='bold'
)

plt.xlabel(
    'Ship Mode',
    fontsize=16,
    color='darkorange'
)

plt.ylabel(
    'Sales',
    fontsize=16,
    color='darkorange'
)
plt.grid(
    axis='y',
    color='lightgray',
    linestyle='--',
    linewidth=0.5
)
for i, value in enumerate(shipmode_sales):

    plt.text(
        i,
        value + 10000,
        f'{value:,.0f}',
        ha='center',
        fontsize=11,
        fontweight='bold'
    )
ax = plt.gca()

ax.spines['top'].set_visible(False)

ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()

# %%
monthly_profit = df.groupby('Month')['Profit'].sum()

# %%
plt.figure(
    figsize=(14,6),
    facecolor='#F5F7FA'
)

monthly_profit.plot(
    kind='line',
    color='#2E8B57',
    linewidth=3,
    marker='o',
    markerfacecolor='#FF8C00',
    markersize=10
)
plt.fill_between(
    monthly_profit.index,
    monthly_profit.values,
    color='#66CDAA',
    alpha=0.3
)
plt.title(
    'Monthly Profit Trend',
    fontsize=24,
    fontweight='bold'
)

plt.xlabel(
    'Month',
    fontsize=16,
    color='darkgreen'
)

plt.ylabel(
    'Profit',
    fontsize=16,
    color='darkgreen'
)
plt.xticks(
    ticks=range(len(monthly_profit.index)),
    labels=monthly_profit.index,
    rotation=45
)
plt.grid(
    axis='y',
    color='lightgray',
    linestyle='--',
    linewidth=0.5
)
ax = plt.gca()

ax.spines['top'].set_visible(False)

ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.raed_csv(r"C:\Users\ADMIN\OneDrive\Desktop\Data Analytics Project\E-Commerce Customer & Sales Analytics Project\Dataset\Sample - Superstore.csv")

# %%
df.head()

# %%
df.info()
